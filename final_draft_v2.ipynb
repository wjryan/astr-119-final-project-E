# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Define a function to evolve x to x_n
# This function takes our initial conditions, evolves x to x_n for a specific r, and saves each evolution of x in an array

# %%
def x_npo_array(x_0, r, n):
    
    a = []
    i = 0
    
    while(i<n+2):
        if(i==0):
            x_npo = 4*r*x_0*(1 - x_0)
            x_n = x_npo
            a.append(x_n)
            i += 1

        elif(i<n+1):
            x_npo = 4*r*x_n*(1 - x_n)
            x_n = x_npo
            a.append(x_n)
            i += 1
            
        elif(i>=n+1):
            i+=1
             
    return(a)

# %% [markdown]
# # Define a function to evolve x to x_n for every R value
# This function evolves an x_n for every value of r and saves it to an array

# %%
def x_npo_array_R_array(r_i,r_n,z):

    r = np.arange(r_i,r_n,z)
    b = []
    i = 0
    
    while(i<len(r)):
        a = x_npo_array(0.65, r[i] ,100)
        b.append(a)
        i += 1
        
        
    return b

# %% [markdown]
# # Define a function that records the nth evolution of x at every value of r

# %%
def x_nth_array(r_i,r_n,z,n):
    
    b = x_npo_array_R_array(r_i,r_n,z)
    r = np.arange(r_i,r_n,z)
    x_n = []
    i = 0
    
    while(i<len(r)):
        x_n.append(b[i][n])
        i += 1 
    
    return x_n

# %% [markdown]
# # Define a function that computes the Lyupanov exponent for a value r

# %%
def lyupanov(z,x,r): # l (L) is Lyupanov exponent
    
    ly=[]  #makes empty array to be filled with l values
    i = 0
    n = len(x)  # how many elements x
    
    while(i<n):   #n being the number of x values per r
        if(i==0):
            t = 4*r*(1-(2*x[z][i]))
            l_0 = 0.5*np.log(np.fabs(t))
            i += 1   #iterates
        
        elif(i<n-1):
            t = 4*r*(1-(2*x[z][i]))
            l = l_0 + 0.5*np.log(np.fabs(t))
            l_0 = l   #defines the new l as l_0 so that we can plug it in summation above.
                #gets the next x value with 
            i += 1 
        else:
            i += 1
            
        # find a way to return array with each l value for corresponding to each r
    return l_0

# %% [markdown]
# # Define a function that creates an array Lyupanov values for every value of r

# %%
def r_loop():
    x = x_npo_array_R_array(0.7,1.0,.01)
    r = np.arange(0.7,1.0,.01)
    l_y = []
    i = 0 
    z = 0
    
    while(i<len(r)): 
        l_y.append(lyupanov(z,x,r[i]))
        i += 1 
        z += 1
        
    return l_y

# %% [markdown]
# # Plotting r vs Lyupanov, and r vs all x iterations

# %%
f, axarr = plt.subplots(1, 2)
f.subplots_adjust(wspace=0.4)
f.set_figheight(7)
f.set_figwidth(17)

b = x_npo_array_R_array(0.7,1.0,0.01)
i = 0

l_y = r_loop()
x_n = x_nth_array(0.7,1.0,0.01,100)
r = np.arange(0.7,1.0,.01)

#first panel - x_npo
while(i+60<len(b[0])-1):
    axarr[0].plot(r[0:31],x_nth_array(0.7,1.0,0.01,i+60),'.',color='red')
    i += 1
axarr[0].set_xlabel('r')
axarr[0].set_ylabel('x_n')
axarr[0].set_title('$x_n\ values$', position=(0.5,1.07))

#second panel - ly
axarr[1].plot(r, l_y)
axarr[1].set_xlabel('r')
axarr[1].set_ylabel('ly')
axarr[1].set_title('$ly\ values$',position=(0.5,1.07))
# Out:
# Text(0.5, 1.07, '$ly\\ values$')

# %% [markdown]
# # Playing with graphs of xn and n (can see bifurcation here)

# %%
b = x_npo_array_R_array(.7,1.0,0.01)
i = 0
while(i<len(b[1])):
    x = i
    y = b[20][i]
    plt.plot(x,y,'o')
    i+=1

# %%
# l_y = r_loop()
i = 0
while(i<len(l_y)):
    x = i
    y = l_y[i]
    plt.plot(x,y,'o')
    i+=1

# %%
b = x_npo_array_R_array(.7,1.0,0.01)
fig = plt.figure(figsize=(7,7))
r = np.arange(0.7,1.00,.01)
plt.plot(r[0:31],b[0:1000])
# Out:
# [<matplotlib.lines.Line2D at 0x124b3c780>,
#  <matplotlib.lines.Line2D at 0x124b3c908>,
#  <matplotlib.lines.Line2D at 0x124b3ca58>,
#  <matplotlib.lines.Line2D at 0x124b3cba8>,
#  <matplotlib.lines.Line2D at 0x124b3ccf8>,
#  <matplotlib.lines.Line2D at 0x124b3ce48>,
#  <matplotlib.lines.Line2D at 0x124b3cf98>,
#  <matplotlib.lines.Line2D at 0x124b44128>,
#  <matplotlib.lines.Line2D at 0x124b44278>,
#  <matplotlib.lines.Line2D at 0x124b443c8>,
#  <matplotlib.lines.Line2D at 0x124b1c4e0>,
#  <matplotlib.lines.Line2D at 0x124b44630>,
#  <matplotlib.lines.Line2D at 0x124b44780>,
#  <matplotlib.lines.Line2D at 0x124b448d0>,
#  <matplotlib.lines.Line2D at 0x124b44a20>,
#  <matplotlib.lines.Line2D at 0x124b44b70>,
#  <matplotlib.lines.Line2D at 0x124b44cc0>,
#  <matplotlib.lines.Line2D at 0x124b44e10>,
#  <matplotlib.lines.Line2D at 0x124b44f60>,
#  <matplotlib.lines.Line2D at 0x124b490f0>,
#  <matplotlib.lines.Line2D at 0x124b49240>,
#  <matplotlib.lines.Line2D at 0x124b49390>,
#  <matplotlib.lines.Line2D at 0x124b494e0>,
#  <matplotlib.lines.Line2D at 0x124b49630>,
#  <matplotlib.lines.Line2D at 0x124b49780>,
#  <matplotlib.lines.Line2D at 0x124b498d0>,
#  <matplotlib.lines.Line2D at 0x124b49a20>,
#  <matplotlib.lines.Line2D at 0x124b49b70>,
#  <matplotlib.lines.Line2D at 0x124b49cc0>,
#  <matplotlib.lines.Line2D at 0x124b49e10>,
#  <matplotlib.lines.Line2D at 0x124b49f60>,
#  <matplotlib.lines.Line2D at 0x124b4e0f0>,
#  <matplotlib.lines.Line2D at 0x124b4e240>,
#  <matplotlib.lines.Line2D at 0x124b4e390>,
#  <matplotlib.lines.Line2D at 0x124b4e4e0>,
#  <matplotlib.lines.Line2D at 0x124b4e630>,
#  <matplotlib.lines.Line2D at 0x124b4e780>,
#  <matplotlib.lines.Line2D at 0x124b4e8d0>,
#  <matplotlib.lines.Line2D at 0x124b4ea20>,
#  <matplotlib.lines.Line2D at 0x124b4eb70>,
#  <matplotlib.lines.Line2D at 0x124b4ecc0>,
#  <matplotlib.lines.Line2D at 0x124b4ee10>,
#  <matplotlib.lines.Line2D at 0x124b4ef60>,
#  <matplotlib.lines.Line2D at 0x124b530f0>,
#  <matplotlib.lines.Line2D at 0x124b53240>,
#  <matplotlib.lines.Line2D at 0x124b53390>,
#  <matplotlib.lines.Line2D at 0x124b534e0>,
#  <matplotlib.lines.Line2D at 0x124b53630>,
#  <matplotlib.lines.Line2D at 0x124b53780>,
#  <matplotlib.lines.Line2D at 0x124b538d0>,
#  <matplotlib.lines.Line2D at 0x124b53a20>,
#  <matplotlib.lines.Line2D at 0x124b53b70>,
#  <matplotlib.lines.Line2D at 0x124b53cc0>,
#  <matplotlib.lines.Line2D at 0x124b53e10>,
#  <matplotlib.lines.Line2D at 0x124b53f60>,
#  <matplotlib.lines.Line2D at 0x124bb50f0>,
#  <matplotlib.lines.Line2D at 0x124bb5240>,
#  <matplotlib.lines.Line2D at 0x124bb5390>,
#  <matplotlib.lines.Line2D at 0x124bb54e0>,
#  <matplotlib.lines.Line2D at 0x124bb5630>,
#  <matplotlib.lines.Line2D at 0x124bb5780>,
#  <matplotlib.lines.Line2D at 0x124bb58d0>,
#  <matplotlib.lines.Line2D at 0x124bb5a20>,
#  <matplotlib.lines.Line2D at 0x124bb5b70>,
#  <matplotlib.lines.Line2D at 0x124bb5cc0>,
#  <matplotlib.lines.Line2D at 0x124bb5e10>,
#  <matplotlib.lines.Line2D at 0x124bb5f60>,
#  <matplotlib.lines.Line2D at 0x124bbc0f0>,
#  <matplotlib.lines.Line2D at 0x124bbc240>,
#  <matplotlib.lines.Line2D at 0x124bbc390>,
#  <matplotlib.lines.Line2D at 0x124bbc4e0>,
#  <matplotlib.lines.Line2D at 0x124bbc630>,
#  <matplotlib.lines.Line2D at 0x124bbc780>,
#  <matplotlib.lines.Line2D at 0x124bbc8d0>,
#  <matplotlib.lines.Line2D at 0x124bbca20>,
#  <matplotlib.lines.Line2D at 0x124bbcb70>,
#  <matplotlib.lines.Line2D at 0x124bbccc0>,
#  <matplotlib.lines.Line2D at 0x124bbce10>,
#  <matplotlib.lines.Line2D at 0x124bbcf60>,
#  <matplotlib.lines.Line2D at 0x124bbf0f0>,
#  <matplotlib.lines.Line2D at 0x124bbf240>,
#  <matplotlib.lines.Line2D at 0x124bbf390>,
#  <matplotlib.lines.Line2D at 0x124bbf4e0>,
#  <matplotlib.lines.Line2D at 0x124bbf630>,
#  <matplotlib.lines.Line2D at 0x124bbf780>,
#  <matplotlib.lines.Line2D at 0x124bbf8d0>,
#  <matplotlib.lines.Line2D at 0x124bbfa20>,
#  <matplotlib.lines.Line2D at 0x124bbfb70>,
#  <matplotlib.lines.Line2D at 0x124bbfcc0>,
#  <matplotlib.lines.Line2D at 0x124bbfe10>,
#  <matplotlib.lines.Line2D at 0x124bbff60>,
#  <matplotlib.lines.Line2D at 0x124bc50f0>,
#  <matplotlib.lines.Line2D at 0x124bc5240>,
#  <matplotlib.lines.Line2D at 0x124bc5390>,
#  <matplotlib.lines.Line2D at 0x124bc54e0>,
#  <matplotlib.lines.Line2D at 0x124bc5630>,
#  <matplotlib.lines.Line2D at 0x124bc5780>,
#  <matplotlib.lines.Line2D at 0x124bc58d0>,
#  <matplotlib.lines.Line2D at 0x124bc5a20>,
#  <matplotlib.lines.Line2D at 0x124bc5b70>,
#  <matplotlib.lines.Line2D at 0x124bc5cc0>]

# %%
b = x_npo_array_R_array(0.7,1.0,0.01)
i = 0
r = np.arange(0.7,1.00,.01)

while(i+70<len(b[0])-1):
    plt.plot(r[0:31],x_nth_array(0.7,1.0,0.01,i+70),'.',color='red')
    i += 1

# %%
b = x_npo_array_R_array(.7,1.0,0.01)
i = 0
while(i<len(b[1])):
    x = i
    y = b[20][i]
    plt.plot(x,y,'o')
    i+=1
